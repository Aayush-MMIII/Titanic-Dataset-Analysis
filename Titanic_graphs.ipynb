# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_cleaned.csv')
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female  28.0      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male  embark_town alive  alone
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# # #Matplotlib graphs

# %%
import matplotlib.pyplot as plt

data = df['survived']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#ffa600')
plt.show()

# %%
data = df['pclass']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#ff6361')
plt.show()

# %%
data = df['sex']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#bc5090')
plt.show()

# %%
data = df['age']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#58508d')
plt.show()

# %%
data = df['sibsp']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#003f5c')
plt.show()

# %%
data = df['parch']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#2f4b7c')
plt.show()

# %%
data = df['fare']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#665191')
plt.show()

# %%
data = df['embarked']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#a05195')
plt.show()

# %%
data = df['class']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#d45087')
plt.show()

# %%
data = df['who']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#f95d6a')
plt.show()

# %%
data = df['embark_town']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#ff7c43')
plt.show()

# %%
data = df['alive']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.hist(data, color='#ffa600')
plt.show()

# %% [markdown]
# # #Seaborn graphs

# %%
import seaborn as sns


sns.countplot(x = 'class', hue = 'who', data = df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(x = 'survived', hue='sex', data = df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x = 'sex', hue='class', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = 'alive', hue = 'who', data = df)
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(x = 'embark_town', hue = 'who', data = df)
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %%
sns.countplot(x = 'alone', hue = 'who', data = df)
# Out:
# <Axes: xlabel='alone', ylabel='count'>

# %%
sns.countplot(x = 'parch', hue = 'who', data = df)
# Out:
# <Axes: xlabel='parch', ylabel='count'>

# %%
sns.countplot(x = 'sibsp', hue = 'who', data = df)
# Out:
# <Axes: xlabel='sibsp', ylabel='count'>

# %%
import matplotlib.pyplot as plt

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
data = df['pclass']
data1 = df['age']
p = plt.subplot()
fig = plt.figure(figsize = (5,5))
p.scatter(data,data1, linewidth=1.0, color="#665191", marker="*", linestyle="--", alpha = 0.5)
plt.show()

# %% [markdown]
# # #Heatmap

# %%
a = [df['fare']]

sns.heatmap(a, annot = True)
# Out:
# <Axes: >
